# %%
# connect to google drive
import os
from google.colab import drive
ROOT_PATH = os.path.join(os.sep, 'content' , 'gdrive')
drive.mount(ROOT_PATH, force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/ProgettoAI/ProgettoAI/SteRoom
# Out:
# /content/gdrive/.shortcut-targets-by-id/1MJ_PV3yImcP5lKaIH7f9wKK1soWaIlGT/ProgettoAI/ProgettoAI/SteRoom

# %% [markdown]
# ### Importing Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import random
from PIL import Image
import warnings
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from skimage import filters
from skimage.color import rgb2gray
from tensorflow.keras.optimizers import Adam

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)

warnings.filterwarnings('ignore')
# Out:
# 2.9.2

# %% [markdown]
# ### Seed

# %%
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# ### Loading Image Dataset

# %%
data_dir = '/content/gdrive/MyDrive/ProgettoAI/ProgettoAI/Processed_dataset'
training_dir = os.path.join(data_dir, 'train')
validation_dir = os.path.join(data_dir, 'val')
test_dir = os.path.join(data_dir, 'test')

# %%
# Input Parameters
img_w = 256
img_h = 256
classes = 3
batch_size = 32

# %%
# Create an ImageDataGenerator object
datagen = ImageDataGenerator()

training_set = datagen.flow_from_directory(
        directory = training_dir,
        class_mode = 'categorical',
        color_mode = 'rgb',
        classes = None,
        seed = seed,
        target_size = (img_h, img_w),
        batch_size = batch_size,
        shuffle = True
    )

validation_set = datagen.flow_from_directory(
        directory = validation_dir,
        class_mode = 'categorical',
        color_mode = 'rgb',
        classes = None,
        seed = seed,
        target_size = (img_h, img_w),
        batch_size = batch_size,
        shuffle = False
    )

test_set = datagen.flow_from_directory(
        directory = test_dir,
        class_mode = 'categorical',
        color_mode = 'rgb',
        classes = None,
        seed = seed,
        target_size = (img_h, img_w),
        batch_size = batch_size,
        shuffle = False
    )
# Out:
# Found 10834 images belonging to 3 classes.
# Found 2327 images belonging to 3 classes.
# Found 2309 images belonging to 3 classes.

# %% [markdown]
# ### Load EfficientNet supernet

# %%
input_shape = (img_h, img_w, 3)

# %%
#Download net
supernet = tf.keras.applications.EfficientNetB3(
    include_top=False,
    weights='imagenet',
    input_shape=(input_shape)
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 [==============================] - 0s 0us/step

# %%
#Classifier
supernet.trainable = False

inputs = tfk.Input(shape=input_shape)
x = supernet(inputs) #one layer is supernet
x = tfkl.GlobalAveragePooling2D(name = 'gap')(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
x = tfkl.Dense(
    512, 
    activation='relu',
    kernel_initializer = tfk.initializers.HeUniform(seed))(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
x = tfkl.Dense(
    128, 
    activation='relu',
    kernel_initializer = tfk.initializers.HeUniform(seed))(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
outputs = tfkl.Dense(
    3, 
    activation='softmax',
    kernel_initializer = tfk.initializers.GlorotUniform(seed))(x)


# Connect input and output through the Model class
tl_model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

# Compile the model
tl_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')
tl_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  efficientnetb3 (Functional)  (None, 8, 8, 1536)       10783535
#
#  gap (GlobalAveragePooling2D  (None, 1536)             0
#  )
#
#  dropout (Dropout)           (None, 1536)              0
#
#  dense (Dense)               (None, 512)               786944
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 11,636,530
# Trainable params: 852,995
# Non-trainable params: 10,783,535
# _________________________________________________________________

# %%
# Callbacks

# Early Stopping 
earlystopping = tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=15, restore_best_weights=True)

# Learning Rate 
learningrate = tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=10, factor=0.1, min_lr=1e-8)

callbacks_list = [earlystopping, learningrate]

# %%
# Train the model
history = tl_model.fit(
    x = training_set,
    epochs = 200,
    validation_data = validation_set,
    callbacks = callbacks_list
).history
# Out:
# Epoch 1/200
# 339/339 [==============================] - 2946s 9s/step - loss: 0.4355 - accuracy: 0.8239 - val_loss: 0.2413 - val_accuracy: 0.9059 - lr: 0.0010
# Epoch 2/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.3077 - accuracy: 0.8776 - val_loss: 0.2498 - val_accuracy: 0.9033 - lr: 0.0010
# Epoch 3/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.2898 - accuracy: 0.8895 - val_loss: 0.2100 - val_accuracy: 0.9205 - lr: 0.0010
# Epoch 4/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.2672 - accuracy: 0.8986 - val_loss: 0.2137 - val_accuracy: 0.9209 - lr: 0.0010
# Epoch 5/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.2508 - accuracy: 0.9069 - val_loss: 0.1988 - val_accuracy: 0.9244 - lr: 0.0010
# Epoch 6/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.2379 - accuracy: 0.9065 - val_loss: 0.2023 - val_accuracy: 0.9248 - lr: 0.0010
# Epoch 7/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.2239 - accuracy: 0.9112 - val_loss: 0.1765 - val_accuracy: 0.9355 - lr: 0.0010
# Epoch 8/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.2254 - accuracy: 0.9130 - val_loss: 0.1878 - val_accuracy: 0.9248 - lr: 0.0010
# Epoch 9/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.2154 - accuracy: 0.9170 - val_loss: 0.1782 - val_accuracy: 0.9265 - lr: 0.0010
# Epoch 10/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.2076 - accuracy: 0.9170 - val_loss: 0.1715 - val_accuracy: 0.9330 - lr: 0.0010
# Epoch 11/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.2077 - accuracy: 0.9206 - val_loss: 0.1783 - val_accuracy: 0.9317 - lr: 0.0010
# Epoch 12/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1993 - accuracy: 0.9245 - val_loss: 0.1689 - val_accuracy: 0.9351 - lr: 0.0010
# Epoch 13/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1920 - accuracy: 0.9246 - val_loss: 0.1727 - val_accuracy: 0.9343 - lr: 0.0010
# Epoch 14/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1947 - accuracy: 0.9260 - val_loss: 0.1862 - val_accuracy: 0.9274 - lr: 0.0010
# Epoch 15/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1892 - accuracy: 0.9278 - val_loss: 0.1645 - val_accuracy: 0.9407 - lr: 0.0010
# Epoch 16/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1823 - accuracy: 0.9308 - val_loss: 0.1645 - val_accuracy: 0.9403 - lr: 0.0010
# Epoch 17/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1820 - accuracy: 0.9323 - val_loss: 0.1659 - val_accuracy: 0.9407 - lr: 0.0010
# Epoch 18/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1787 - accuracy: 0.9300 - val_loss: 0.1621 - val_accuracy: 0.9364 - lr: 0.0010
# Epoch 19/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1747 - accuracy: 0.9338 - val_loss: 0.1712 - val_accuracy: 0.9381 - lr: 0.0010
# Epoch 20/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1709 - accuracy: 0.9357 - val_loss: 0.1714 - val_accuracy: 0.9312 - lr: 0.0010
# Epoch 21/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1726 - accuracy: 0.9346 - val_loss: 0.1714 - val_accuracy: 0.9330 - lr: 0.0010
# Epoch 22/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1690 - accuracy: 0.9346 - val_loss: 0.1534 - val_accuracy: 0.9446 - lr: 0.0010
# Epoch 23/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1636 - accuracy: 0.9390 - val_loss: 0.1720 - val_accuracy: 0.9398 - lr: 0.0010
# Epoch 24/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1597 - accuracy: 0.9378 - val_loss: 0.1644 - val_accuracy: 0.9377 - lr: 0.0010
# Epoch 25/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1565 - accuracy: 0.9386 - val_loss: 0.1611 - val_accuracy: 0.9403 - lr: 0.0010
# Epoch 26/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1564 - accuracy: 0.9401 - val_loss: 0.1549 - val_accuracy: 0.9403 - lr: 0.0010
# Epoch 27/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1586 - accuracy: 0.9394 - val_loss: 0.1641 - val_accuracy: 0.9385 - lr: 0.0010
# Epoch 28/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1507 - accuracy: 0.9418 - val_loss: 0.1668 - val_accuracy: 0.9424 - lr: 0.0010
# Epoch 29/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1512 - accuracy: 0.9415 - val_loss: 0.1566 - val_accuracy: 0.9411 - lr: 0.0010
# Epoch 30/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1460 - accuracy: 0.9445 - val_loss: 0.1553 - val_accuracy: 0.9407 - lr: 0.0010
# Epoch 31/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1480 - accuracy: 0.9445 - val_loss: 0.1597 - val_accuracy: 0.9428 - lr: 0.0010
# Epoch 32/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1455 - accuracy: 0.9419 - val_loss: 0.1503 - val_accuracy: 0.9424 - lr: 0.0010
# Epoch 33/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1275 - accuracy: 0.9505 - val_loss: 0.1475 - val_accuracy: 0.9459 - lr: 1.0000e-04
# Epoch 34/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1184 - accuracy: 0.9560 - val_loss: 0.1481 - val_accuracy: 0.9484 - lr: 1.0000e-04
# Epoch 35/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1203 - accuracy: 0.9542 - val_loss: 0.1461 - val_accuracy: 0.9497 - lr: 1.0000e-04
# Epoch 36/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1168 - accuracy: 0.9556 - val_loss: 0.1480 - val_accuracy: 0.9480 - lr: 1.0000e-04
# Epoch 37/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1137 - accuracy: 0.9582 - val_loss: 0.1475 - val_accuracy: 0.9502 - lr: 1.0000e-04
# Epoch 38/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1154 - accuracy: 0.9558 - val_loss: 0.1481 - val_accuracy: 0.9514 - lr: 1.0000e-04
# Epoch 39/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1104 - accuracy: 0.9595 - val_loss: 0.1503 - val_accuracy: 0.9497 - lr: 1.0000e-04
# Epoch 40/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1073 - accuracy: 0.9610 - val_loss: 0.1490 - val_accuracy: 0.9484 - lr: 1.0000e-04
# Epoch 41/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1126 - accuracy: 0.9560 - val_loss: 0.1485 - val_accuracy: 0.9510 - lr: 1.0000e-04
# Epoch 42/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1090 - accuracy: 0.9561 - val_loss: 0.1450 - val_accuracy: 0.9480 - lr: 1.0000e-04
# Epoch 43/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1104 - accuracy: 0.9590 - val_loss: 0.1475 - val_accuracy: 0.9476 - lr: 1.0000e-04
# Epoch 44/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1083 - accuracy: 0.9574 - val_loss: 0.1455 - val_accuracy: 0.9493 - lr: 1.0000e-04
# Epoch 45/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1045 - accuracy: 0.9596 - val_loss: 0.1483 - val_accuracy: 0.9510 - lr: 1.0000e-04
# Epoch 46/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1010 - accuracy: 0.9628 - val_loss: 0.1478 - val_accuracy: 0.9497 - lr: 1.0000e-04
# Epoch 47/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1068 - accuracy: 0.9572 - val_loss: 0.1486 - val_accuracy: 0.9514 - lr: 1.0000e-04
# Epoch 48/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1011 - accuracy: 0.9607 - val_loss: 0.1488 - val_accuracy: 0.9502 - lr: 1.0000e-04
# Epoch 49/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.0998 - accuracy: 0.9629 - val_loss: 0.1482 - val_accuracy: 0.9519 - lr: 1.0000e-05
# Epoch 50/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1069 - accuracy: 0.9614 - val_loss: 0.1481 - val_accuracy: 0.9514 - lr: 1.0000e-05
# Epoch 51/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1000 - accuracy: 0.9614 - val_loss: 0.1483 - val_accuracy: 0.9523 - lr: 1.0000e-05
# Epoch 52/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1032 - accuracy: 0.9601 - val_loss: 0.1484 - val_accuracy: 0.9514 - lr: 1.0000e-05
# Epoch 53/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1025 - accuracy: 0.9616 - val_loss: 0.1483 - val_accuracy: 0.9510 - lr: 1.0000e-05
# Epoch 54/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.0991 - accuracy: 0.9633 - val_loss: 0.1480 - val_accuracy: 0.9506 - lr: 1.0000e-05
# Epoch 55/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1017 - accuracy: 0.9606 - val_loss: 0.1476 - val_accuracy: 0.9510 - lr: 1.0000e-05
# Epoch 56/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1007 - accuracy: 0.9621 - val_loss: 0.1480 - val_accuracy: 0.9514 - lr: 1.0000e-05
# Epoch 57/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1032 - accuracy: 0.9614 - val_loss: 0.1479 - val_accuracy: 0.9519 - lr: 1.0000e-05
# Epoch 58/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.0970 - accuracy: 0.9608 - val_loss: 0.1479 - val_accuracy: 0.9514 - lr: 1.0000e-05
# Epoch 59/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.0956 - accuracy: 0.9634 - val_loss: 0.1482 - val_accuracy: 0.9519 - lr: 1.0000e-05
# Epoch 60/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.0959 - accuracy: 0.9642 - val_loss: 0.1486 - val_accuracy: 0.9514 - lr: 1.0000e-05
# Epoch 61/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.0992 - accuracy: 0.9647 - val_loss: 0.1485 - val_accuracy: 0.9514 - lr: 1.0000e-05
# Epoch 62/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.0964 - accuracy: 0.9658 - val_loss: 0.1485 - val_accuracy: 0.9514 - lr: 1.0000e-06
# Epoch 63/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.0987 - accuracy: 0.9637 - val_loss: 0.1485 - val_accuracy: 0.9510 - lr: 1.0000e-06
# Epoch 64/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.1050 - accuracy: 0.9610 - val_loss: 0.1484 - val_accuracy: 0.9510 - lr: 1.0000e-06
# Epoch 65/200
# 339/339 [==============================] - 64s 189ms/step - loss: 0.1024 - accuracy: 0.9610 - val_loss: 0.1484 - val_accuracy: 0.9510 - lr: 1.0000e-06
# Epoch 66/200
# 339/339 [==============================] - 64s 188ms/step - loss: 0.0997 - accuracy: 0.9610 - val_loss: 0.1484 - val_accuracy: 0.9510 - lr: 1.0000e-06

# %%
# Plot the training

# Loss Function
plt.figure(figsize=(10,5))
plt.plot(history['loss'], label='Training', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

# Accuracy
plt.figure(figsize=(10,5))
plt.plot(history['accuracy'], label='Training', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

# %%
[test_loss, test_accuracy] = tl_model.evaluate(test_set)
# Out:
# 73/73 [==============================] - 719s 10s/step - loss: 0.1875 - accuracy: 0.9233

# %%
labels = ['N', 'P', 'T']

# %%
#Confusion matrix
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

predictions = tl_model.predict_generator(test_set)
predicted_classes = np.argmax(predictions, axis=-1)

# Compute the confusion matrix

cm = (confusion_matrix(test_set.classes, predicted_classes))

# Compute the classification metrics
accuracy = accuracy_score(test_set.classes, predicted_classes)
precision = precision_score(test_set.classes, predicted_classes, average='macro')
recall = recall_score(test_set.classes, predicted_classes, average='macro')
f1 = f1_score(test_set.classes, predicted_classes, average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, xticklabels=labels, yticklabels=labels)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.463
# Precision: 0.339
# Recall: 0.3387
# F1: 0.3386

# %%
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix


def print_evaluation(y_true, predictions):
    cm = confusion_matrix(y_true, predictions, normalize='pred')
    cm_display = ConfusionMatrixDisplay(cm, display_labels = ['N', 'P', 'T'])
    cm_display.plot()
    
    print(classification_report(y_true, predictions, digits = 4))

# %%
#cf on validation for comparisons
val_predictions = tl_model.predict(validation_set)
# Out:
# 73/73 [==============================] - 12s 142ms/step

# %%
y_val = validation_set.labels

# %%
print_evaluation(y_val, np.argmax(val_predictions, axis=-1))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9525    0.9739    0.9631      1420
#            1     0.9688    0.9795    0.9742       635
#            2     0.9056    0.7757    0.8356       272
#
#     accuracy                         0.9523      2327
#    macro avg     0.9423    0.9097    0.9243      2327
# weighted avg     0.9515    0.9523    0.9512      2327

# %%
test_predictions = tl_model.predict(test_set)
# Out:
# 73/73 [==============================] - 487s 7s/step

# %%
y_test = test_set.labels

# %%
print_evaluation(y_test, np.argmax(test_predictions, axis=-1))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9420    0.9677    0.9546      1392
#            1     0.9593    0.9669    0.9631       634
#            2     0.9125    0.7739    0.8375       283
#
#     accuracy                         0.9437      2309
#    macro avg     0.9379    0.9028    0.9184      2309
# weighted avg     0.9431    0.9437    0.9426      2309

# %% [markdown]
# ### Save Model

# %%
tl_model.save('effB3_frozen')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 130). These functions will not be directly callable after loading.
