# %% [markdown]
# In this notebook we train:
# - EfficientNetB2, classifier only
# - EfficientNetB2, whole network
#
# **Dataset**: pre-processed, without class-weights

# %% [markdown]
# ### Environment

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import random
from PIL import Image
import warnings
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from skimage import filters
from skimage.color import rgb2gray
from tensorflow.keras.optimizers import Adam

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)

warnings.filterwarnings('ignore')
# Out:
# 2.6.4

# %%
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# ### Dataset

# %%
data_dir = '/kaggle/input/corino-preprocessed'
training_dir = os.path.join(data_dir, 'train')
validation_dir = os.path.join(data_dir, 'val')
test_dir = os.path.join(data_dir, 'test')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

h = 256
w = 256

#imageDataGenerator
train_set = ImageDataGenerator().flow_from_directory(directory = training_dir,
                                                     target_size = (h, w),
                                                     color_mode = 'rgb',
                                                     classes = None,
                                                     class_mode = 'categorical',
                                                     batch_size = 32, 
                                                     shuffle = True,
                                                     seed = seed)

validation_set = ImageDataGenerator().flow_from_directory(directory = validation_dir,
                                                     target_size = (h, w),
                                                     color_mode = 'rgb',
                                                     classes = None,
                                                     class_mode = 'categorical',
                                                     batch_size = 32, 
                                                     shuffle = False,
                                                     seed = seed)

test_set = ImageDataGenerator().flow_from_directory(directory = test_dir,
                                                     target_size = (h, w),
                                                     color_mode = 'rgb',
                                                     classes = None,
                                                     class_mode = 'categorical',
                                                     batch_size = 32, 
                                                     shuffle = False,
                                                     seed = seed)
# Out:
# Found 10834 images belonging to 3 classes.
# Found 2327 images belonging to 3 classes.
# Found 2309 images belonging to 3 classes.

# %% [markdown]
# ### Transfer Learning

# %%
input_shape = (256, 256, 3)

# %%
import keras.backend as K
def f1(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
#Download net
supernet = tf.keras.applications.efficientnet.EfficientNetB2(
    include_top=False,
    weights='imagenet',
    input_shape=(input_shape)
)

#supernet.summary()
#tfk.utils.plot_model(supernet)
# Out:
# 2023-02-01 10:51:40.038042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:40.039012: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:40.122985: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:40.123827: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:40.124597: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:40.125296: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:40.127240: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-01 10:51:40.387238: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:40.388219: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:40.389057: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:40.389792: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:40.390701: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:40.391403: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:42.849150: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:42.850101: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:42.850842: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:42.851599: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:42.852321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:42.853014: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2023-02-01 10:51:42.855568: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-01 10:51:42.856279: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31793152/31790344 [==============================] - 0s 0us/step
# 31801344/31790344 [==============================] - 0s 0us/step

# %%
#Classifier
supernet.trainable = False

inputs = tfk.Input(shape=input_shape)
x = supernet(inputs) #one layer is supernet
x = tfkl.GlobalAveragePooling2D(name = 'gap')(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
x = tfkl.Dense(
    512, 
    activation='relu',
    kernel_initializer = tfk.initializers.HeUniform(seed))(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
x = tfkl.Dense(
    128, 
    activation='relu',
    kernel_initializer = tfk.initializers.HeUniform(seed))(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
outputs = tfkl.Dense(
    3, 
    activation='softmax',
    kernel_initializer = tfk.initializers.GlorotUniform(seed))(x)


# Connect input and output through the Model class
tl_model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

# Compile the model
tl_model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                 optimizer=tfk.optimizers.Adam(1e-3),
                 metrics=['accuracy',
                          tf.keras.metrics.Recall(name='recall'),
                          tf.keras.metrics.Precision(name='precision'),
                          f1])
tl_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# efficientnetb2 (Functional)  (None, 8, 8, 1408)        7768569
# _________________________________________________________________
# gap (GlobalAveragePooling2D) (None, 1408)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1408)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               721408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 8,556,028
# Trainable params: 787,459
# Non-trainable params: 7,768,569
# _________________________________________________________________

# %%
# Train the model
history = tl_model.fit(
    x = train_set,
    epochs = 200,
    validation_data = validation_set,
    callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_f1', patience=10, restore_best_weights=True, mode='max'),
                 tf.keras.callbacks.ReduceLROnPlateau(monitor='val_f1', patience=5, factor=0.1, verbose=1, mode='max')]
).history
# Out:
# 2023-02-01 10:51:47.113932: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2023-02-01 10:51:56.503883: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 339/339 [==============================] - 136s 356ms/step - loss: 0.4519 - accuracy: 0.8171 - recall: 0.8022 - precision: 0.8294 - f1: 0.8146 - val_loss: 0.2773 - val_accuracy: 0.8930 - val_recall: 0.8831 - val_precision: 0.9017 - val_f1: 0.8902
# Epoch 2/200
# 339/339 [==============================] - 51s 149ms/step - loss: 0.3288 - accuracy: 0.8664 - recall: 0.8608 - precision: 0.8715 - f1: 0.8661 - val_loss: 0.2390 - val_accuracy: 0.9080 - val_recall: 0.9042 - val_precision: 0.9120 - val_f1: 0.9064
# Epoch 3/200
# 339/339 [==============================] - 50s 148ms/step - loss: 0.2979 - accuracy: 0.8809 - recall: 0.8770 - precision: 0.8860 - f1: 0.8815 - val_loss: 0.2401 - val_accuracy: 0.9093 - val_recall: 0.9046 - val_precision: 0.9144 - val_f1: 0.9084
# Epoch 4/200
# 339/339 [==============================] - 50s 149ms/step - loss: 0.2709 - accuracy: 0.8911 - recall: 0.8864 - precision: 0.8939 - f1: 0.8901 - val_loss: 0.2145 - val_accuracy: 0.9209 - val_recall: 0.9171 - val_precision: 0.9226 - val_f1: 0.9182
# Epoch 5/200
# 339/339 [==============================] - 50s 147ms/step - loss: 0.2638 - accuracy: 0.8951 - recall: 0.8903 - precision: 0.8996 - f1: 0.8948 - val_loss: 0.1963 - val_accuracy: 0.9196 - val_recall: 0.9188 - val_precision: 0.9227 - val_f1: 0.9198
# Epoch 6/200
# 339/339 [==============================] - 50s 148ms/step - loss: 0.2402 - accuracy: 0.9040 - recall: 0.9007 - precision: 0.9065 - f1: 0.9035 - val_loss: 0.2116 - val_accuracy: 0.9145 - val_recall: 0.9136 - val_precision: 0.9148 - val_f1: 0.9126
# Epoch 7/200
# 339/339 [==============================] - 50s 147ms/step - loss: 0.2401 - accuracy: 0.9069 - recall: 0.9047 - precision: 0.9092 - f1: 0.9070 - val_loss: 0.1832 - val_accuracy: 0.9261 - val_recall: 0.9252 - val_precision: 0.9276 - val_f1: 0.9256
# Epoch 8/200
# 339/339 [==============================] - 51s 149ms/step - loss: 0.2246 - accuracy: 0.9128 - recall: 0.9100 - precision: 0.9151 - f1: 0.9126 - val_loss: 0.1935 - val_accuracy: 0.9222 - val_recall: 0.9145 - val_precision: 0.9276 - val_f1: 0.9200
# Epoch 9/200
# 339/339 [==============================] - 50s 149ms/step - loss: 0.2145 - accuracy: 0.9142 - recall: 0.9109 - precision: 0.9163 - f1: 0.9135 - val_loss: 0.1883 - val_accuracy: 0.9235 - val_recall: 0.9209 - val_precision: 0.9249 - val_f1: 0.9223
# Epoch 10/200
# 339/339 [==============================] - 50s 148ms/step - loss: 0.2134 - accuracy: 0.9147 - recall: 0.9130 - precision: 0.9159 - f1: 0.9145 - val_loss: 0.1892 - val_accuracy: 0.9274 - val_recall: 0.9274 - val_precision: 0.9290 - val_f1: 0.9272
# Epoch 11/200
# 339/339 [==============================] - 50s 148ms/step - loss: 0.2098 - accuracy: 0.9164 - recall: 0.9143 - precision: 0.9185 - f1: 0.9164 - val_loss: 0.1658 - val_accuracy: 0.9398 - val_recall: 0.9373 - val_precision: 0.9421 - val_f1: 0.9388
# Epoch 12/200
# 339/339 [==============================] - 50s 147ms/step - loss: 0.2031 - accuracy: 0.9192 - recall: 0.9162 - precision: 0.9215 - f1: 0.9188 - val_loss: 0.1726 - val_accuracy: 0.9334 - val_recall: 0.9330 - val_precision: 0.9346 - val_f1: 0.9332
# Epoch 13/200
# 339/339 [==============================] - 51s 149ms/step - loss: 0.2053 - accuracy: 0.9181 - recall: 0.9158 - precision: 0.9202 - f1: 0.9178 - val_loss: 0.1678 - val_accuracy: 0.9385 - val_recall: 0.9325 - val_precision: 0.9386 - val_f1: 0.9349
# Epoch 14/200
# 339/339 [==============================] - 50s 148ms/step - loss: 0.1945 - accuracy: 0.9227 - recall: 0.9200 - precision: 0.9248 - f1: 0.9224 - val_loss: 0.1695 - val_accuracy: 0.9377 - val_recall: 0.9373 - val_precision: 0.9393 - val_f1: 0.9373
# Epoch 15/200
# 339/339 [==============================] - 50s 147ms/step - loss: 0.1912 - accuracy: 0.9268 - recall: 0.9244 - precision: 0.9289 - f1: 0.9266 - val_loss: 0.1632 - val_accuracy: 0.9377 - val_recall: 0.9312 - val_precision: 0.9409 - val_f1: 0.9354
# Epoch 16/200
# 339/339 [==============================] - 50s 148ms/step - loss: 0.1855 - accuracy: 0.9269 - recall: 0.9251 - precision: 0.9289 - f1: 0.9268 - val_loss: 0.1543 - val_accuracy: 0.9385 - val_recall: 0.9381 - val_precision: 0.9393 - val_f1: 0.9380
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 17/200
# 339/339 [==============================] - 50s 147ms/step - loss: 0.1604 - accuracy: 0.9356 - recall: 0.9341 - precision: 0.9363 - f1: 0.9352 - val_loss: 0.1464 - val_accuracy: 0.9424 - val_recall: 0.9420 - val_precision: 0.9436 - val_f1: 0.9421
# Epoch 18/200
# 339/339 [==============================] - 50s 148ms/step - loss: 0.1526 - accuracy: 0.9415 - recall: 0.9397 - precision: 0.9430 - f1: 0.9413 - val_loss: 0.1429 - val_accuracy: 0.9411 - val_recall: 0.9403 - val_precision: 0.9419 - val_f1: 0.9402
# Epoch 19/200
# 339/339 [==============================] - 50s 148ms/step - loss: 0.1592 - accuracy: 0.9388 - recall: 0.9370 - precision: 0.9404 - f1: 0.9385 - val_loss: 0.1414 - val_accuracy: 0.9424 - val_recall: 0.9411 - val_precision: 0.9432 - val_f1: 0.9412
# Epoch 20/200
# 339/339 [==============================] - 50s 146ms/step - loss: 0.1448 - accuracy: 0.9440 - recall: 0.9429 - precision: 0.9450 - f1: 0.9440 - val_loss: 0.1407 - val_accuracy: 0.9459 - val_recall: 0.9454 - val_precision: 0.9462 - val_f1: 0.9450
# Epoch 21/200
# 339/339 [==============================] - 50s 147ms/step - loss: 0.1503 - accuracy: 0.9434 - recall: 0.9419 - precision: 0.9452 - f1: 0.9435 - val_loss: 0.1409 - val_accuracy: 0.9493 - val_recall: 0.9476 - val_precision: 0.9492 - val_f1: 0.9477
# Epoch 22/200
# 339/339 [==============================] - 50s 147ms/step - loss: 0.1482 - accuracy: 0.9424 - recall: 0.9415 - precision: 0.9442 - f1: 0.9427 - val_loss: 0.1380 - val_accuracy: 0.9446 - val_recall: 0.9437 - val_precision: 0.9466 - val_f1: 0.9442
# Epoch 23/200
# 339/339 [==============================] - 50s 147ms/step - loss: 0.1422 - accuracy: 0.9446 - recall: 0.9430 - precision: 0.9457 - f1: 0.9442 - val_loss: 0.1393 - val_accuracy: 0.9476 - val_recall: 0.9471 - val_precision: 0.9488 - val_f1: 0.9471
# Epoch 24/200
# 339/339 [==============================] - 50s 149ms/step - loss: 0.1443 - accuracy: 0.9450 - recall: 0.9437 - precision: 0.9469 - f1: 0.9452 - val_loss: 0.1385 - val_accuracy: 0.9489 - val_recall: 0.9480 - val_precision: 0.9500 - val_f1: 0.9481
# Epoch 25/200
# 339/339 [==============================] - 51s 149ms/step - loss: 0.1414 - accuracy: 0.9460 - recall: 0.9451 - precision: 0.9473 - f1: 0.9461 - val_loss: 0.1396 - val_accuracy: 0.9489 - val_recall: 0.9489 - val_precision: 0.9497 - val_f1: 0.9486
# Epoch 26/200
# 339/339 [==============================] - 51s 152ms/step - loss: 0.1445 - accuracy: 0.9449 - recall: 0.9436 - precision: 0.9459 - f1: 0.9448 - val_loss: 0.1385 - val_accuracy: 0.9484 - val_recall: 0.9480 - val_precision: 0.9496 - val_f1: 0.9479
# Epoch 27/200
# 339/339 [==============================] - 51s 149ms/step - loss: 0.1343 - accuracy: 0.9475 - recall: 0.9466 - precision: 0.9490 - f1: 0.9479 - val_loss: 0.1381 - val_accuracy: 0.9471 - val_recall: 0.9467 - val_precision: 0.9475 - val_f1: 0.9464
# Epoch 28/200
# 339/339 [==============================] - 50s 147ms/step - loss: 0.1351 - accuracy: 0.9448 - recall: 0.9437 - precision: 0.9460 - f1: 0.9447 - val_loss: 0.1360 - val_accuracy: 0.9480 - val_recall: 0.9476 - val_precision: 0.9484 - val_f1: 0.9473
# Epoch 29/200
# 339/339 [==============================] - 50s 148ms/step - loss: 0.1382 - accuracy: 0.9455 - recall: 0.9446 - precision: 0.9469 - f1: 0.9458 - val_loss: 0.1388 - val_accuracy: 0.9471 - val_recall: 0.9467 - val_precision: 0.9479 - val_f1: 0.9466
# Epoch 30/200
# 339/339 [==============================] - 50s 146ms/step - loss: 0.1384 - accuracy: 0.9465 - recall: 0.9452 - precision: 0.9472 - f1: 0.9459 - val_loss: 0.1401 - val_accuracy: 0.9489 - val_recall: 0.9480 - val_precision: 0.9488 - val_f1: 0.9477
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 31/200
# 339/339 [==============================] - 50s 148ms/step - loss: 0.1371 - accuracy: 0.9449 - recall: 0.9435 - precision: 0.9455 - f1: 0.9446 - val_loss: 0.1388 - val_accuracy: 0.9480 - val_recall: 0.9471 - val_precision: 0.9480 - val_f1: 0.9469
# Epoch 32/200
# 339/339 [==============================] - 50s 146ms/step - loss: 0.1333 - accuracy: 0.9478 - recall: 0.9470 - precision: 0.9491 - f1: 0.9480 - val_loss: 0.1382 - val_accuracy: 0.9484 - val_recall: 0.9471 - val_precision: 0.9484 - val_f1: 0.9470
# Epoch 33/200
# 339/339 [==============================] - 50s 147ms/step - loss: 0.1327 - accuracy: 0.9476 - recall: 0.9472 - precision: 0.9483 - f1: 0.9478 - val_loss: 0.1377 - val_accuracy: 0.9484 - val_recall: 0.9471 - val_precision: 0.9488 - val_f1: 0.9472
# Epoch 34/200
# 339/339 [==============================] - 50s 148ms/step - loss: 0.1273 - accuracy: 0.9503 - recall: 0.9489 - precision: 0.9509 - f1: 0.9498 - val_loss: 0.1371 - val_accuracy: 0.9480 - val_recall: 0.9467 - val_precision: 0.9483 - val_f1: 0.9468
# Epoch 35/200
# 339/339 [==============================] - 50s 146ms/step - loss: 0.1344 - accuracy: 0.9487 - recall: 0.9471 - precision: 0.9503 - f1: 0.9486 - val_loss: 0.1370 - val_accuracy: 0.9489 - val_recall: 0.9480 - val_precision: 0.9496 - val_f1: 0.9481
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.

# %% [markdown]
# ### Transfer Learning: results

# %%
# Plot the training

# loss
plt.figure(figsize=(10,5))
plt.plot(history['loss'], label='Training', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

# Accuracy
plt.figure(figsize=(10,5))
plt.plot(history['accuracy'], label='Training', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

# %%
tl_model.save('/kaggle/working')
# Out:
# 2023-02-01 11:28:27.241303: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.

# %%
# !zip -r efficientnetb2.zip /kaggle/working
from IPython.display import FileLink 
FileLink(r'efficientnetb2.zip')
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/variables/ (stored 0%)
#   adding: kaggle/working/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: kaggle/working/variables/variables.index (deflated 74%)
#   adding: kaggle/working/assets/ (stored 0%)
#   adding: kaggle/working/__notebook_source__.ipynb (deflated 44%)
#   adding: kaggle/working/keras_metadata.pb (deflated 96%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
#   adding: kaggle/working/saved_model.pb (deflated 91%)
# /kaggle/working/efficientnetb2.zip

# %% [markdown]
# ##### Validation

# %%
#cf on validation for comparisons
val_predictions = tl_model.predict(validation_set)

# %%
tl_model.evaluate(validation_set)
# Out:
# 73/73 [==============================] - 9s 121ms/step - loss: 0.1396 - accuracy: 0.9489 - recall: 0.9489 - precision: 0.9497 - f1: 0.9486
# [0.13956265151500702,
#  0.9488611817359924,
#  0.9488611817359924,
#  0.9496774077415466,
#  0.9485672116279602]

# %%
val_predictions = tl_model.predict(validation_set)
y_val = validation_set.labels

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
def print_evaluation(y_true, predictions):
    cm = confusion_matrix(y_true, predictions, normalize='pred')
    cm_display = ConfusionMatrixDisplay(cm, display_labels = ['N', 'P', 'T'])
    cm_display.plot()
    
    print(classification_report(y_true, predictions, digits=4))

# %%
print_evaluation(y_val, np.argmax(val_predictions, axis=-1))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9541    0.9662    0.9601      1420
#            1     0.9569    0.9780    0.9673       635
#            2     0.8958    0.7904    0.8398       272
#
#     accuracy                         0.9489      2327
#    macro avg     0.9356    0.9115    0.9224      2327
# weighted avg     0.9480    0.9489    0.9480      2327

# %% [markdown]
# ##### Test

# %%
tl_model.evaluate(test_set)
# Out:
# 73/73 [==============================] - 23s 313ms/step - loss: 0.1603 - accuracy: 0.9376 - recall: 0.9372 - precision: 0.9380 - f1: 0.9360
# [0.16028062999248505,
#  0.9376353621482849,
#  0.9372022747993469,
#  0.9380147457122803,
#  0.9360241889953613]

# %%
val_predictions = tl_model.predict(test_set)
y_val = test_set.labels

# %%
print_evaluation(y_val, np.argmax(val_predictions, axis=-1))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9439    0.9547    0.9493      1392
#            1     0.9433    0.9700    0.9565       634
#            2     0.8876    0.7809    0.8308       283
#
#     accuracy                         0.9376      2309
#    macro avg     0.9249    0.9019    0.9122      2309
# weighted avg     0.9368    0.9376    0.9367      2309

# %% [markdown]
# ### Fine Tuning

# %%
# Set all VGG16 layers to True
tl_model .get_layer('efficientnetb2').trainable = True
# Freeze first N layers, e.g., until 14th
for i, layer in enumerate(tl_model.get_layer('efficientnetb2').layers):
  layer.trainable = True
for i, layer in enumerate(tl_model.get_layer('efficientnetb2').layers):
   print(i, layer.name, layer.trainable)
tl_model.summary()
# Out:
# 0 input_1 True
# 1 rescaling True
# 2 normalization True
# 3 stem_conv_pad True
# 4 stem_conv True
# 5 stem_bn True
# 6 stem_activation True
# 7 block1a_dwconv True
# 8 block1a_bn True
# 9 block1a_activation True
# 10 block1a_se_squeeze True
# 11 block1a_se_reshape True
# 12 block1a_se_reduce True
# 13 block1a_se_expand True
# 14 block1a_se_excite True
# 15 block1a_project_conv True
# 16 block1a_project_bn True
# 17 block1b_dwconv True
# 18 block1b_bn True
# 19 block1b_activation True
# 20 block1b_se_squeeze True
# 21 block1b_se_reshape True
# 22 block1b_se_reduce True
# 23 block1b_se_expand True
# 24 block1b_se_excite True
# 25 block1b_project_conv True
# 26 block1b_project_bn True
# 27 block1b_drop True
# 28 block1b_add True
# 29 block2a_expand_conv True
# 30 block2a_expand_bn True
# 31 block2a_expand_activation True
# 32 block2a_dwconv_pad True
# 33 block2a_dwconv True
# 34 block2a_bn True
# 35 block2a_activation True
# 36 block2a_se_squeeze True
# 37 block2a_se_reshape True
# 38 block2a_se_reduce True
# 39 block2a_se_expand True
# 40 block2a_se_excite True
# 41 block2a_project_conv True
# 42 block2a_project_bn True
# 43 block2b_expand_conv True
# 44 block2b_expand_bn True
# 45 block2b_expand_activation True
# 46 block2b_dwconv True
# 47 block2b_bn True
# 48 block2b_activation True
# 49 block2b_se_squeeze True
# 50 block2b_se_reshape True
# 51 block2b_se_reduce True
# 52 block2b_se_expand True
# 53 block2b_se_excite True
# 54 block2b_project_conv True
# 55 block2b_project_bn True
# 56 block2b_drop True
# 57 block2b_add True
# 58 block2c_expand_conv True
# 59 block2c_expand_bn True
# 60 block2c_expand_activation True
# 61 block2c_dwconv True
# 62 block2c_bn True
# 63 block2c_activation True
# 64 block2c_se_squeeze True
# 65 block2c_se_reshape True
# 66 block2c_se_reduce True
# 67 block2c_se_expand True
# 68 block2c_se_excite True
# 69 block2c_project_conv True
# 70 block2c_project_bn True
# 71 block2c_drop True
# 72 block2c_add True
# 73 block3a_expand_conv True
# 74 block3a_expand_bn True
# 75 block3a_expand_activation True
# 76 block3a_dwconv_pad True
# 77 block3a_dwconv True
# 78 block3a_bn True
# 79 block3a_activation True
# 80 block3a_se_squeeze True
# 81 block3a_se_reshape True
# 82 block3a_se_reduce True
# 83 block3a_se_expand True
# 84 block3a_se_excite True
# 85 block3a_project_conv True
# 86 block3a_project_bn True
# 87 block3b_expand_conv True
# 88 block3b_expand_bn True
# 89 block3b_expand_activation True
# 90 block3b_dwconv True
# 91 block3b_bn True
# 92 block3b_activation True
# 93 block3b_se_squeeze True
# 94 block3b_se_reshape True
# 95 block3b_se_reduce True
# 96 block3b_se_expand True
# 97 block3b_se_excite True
# 98 block3b_project_conv True
# 99 block3b_project_bn True
# 100 block3b_drop True
# 101 block3b_add True
# 102 block3c_expand_conv True
# 103 block3c_expand_bn True
# 104 block3c_expand_activation True
# 105 block3c_dwconv True
# 106 block3c_bn True
# 107 block3c_activation True
# 108 block3c_se_squeeze True
# 109 block3c_se_reshape True
# 110 block3c_se_reduce True
# 111 block3c_se_expand True
# 112 block3c_se_excite True
# 113 block3c_project_conv True
# 114 block3c_project_bn True
# 115 block3c_drop True
# 116 block3c_add True
# 117 block4a_expand_conv True
# 118 block4a_expand_bn True
# 119 block4a_expand_activation True
# 120 block4a_dwconv_pad True
# 121 block4a_dwconv True
# 122 block4a_bn True
# 123 block4a_activation True
# 124 block4a_se_squeeze True
# 125 block4a_se_reshape True
# 126 block4a_se_reduce True
# 127 block4a_se_expand True
# 128 block4a_se_excite True
# 129 block4a_project_conv True
# 130 block4a_project_bn True
# 131 block4b_expand_conv True
# 132 block4b_expand_bn True
# 133 block4b_expand_activation True
# 134 block4b_dwconv True
# 135 block4b_bn True
# 136 block4b_activation True
# 137 block4b_se_squeeze True
# 138 block4b_se_reshape True
# 139 block4b_se_reduce True
# 140 block4b_se_expand True
# 141 block4b_se_excite True
# 142 block4b_project_conv True
# 143 block4b_project_bn True
# 144 block4b_drop True
# 145 block4b_add True
# 146 block4c_expand_conv True
# 147 block4c_expand_bn True
# 148 block4c_expand_activation True
# 149 block4c_dwconv True
# 150 block4c_bn True
# 151 block4c_activation True
# 152 block4c_se_squeeze True
# 153 block4c_se_reshape True
# 154 block4c_se_reduce True
# 155 block4c_se_expand True
# 156 block4c_se_excite True
# 157 block4c_project_conv True
# 158 block4c_project_bn True
# 159 block4c_drop True
# 160 block4c_add True
# 161 block4d_expand_conv True
# 162 block4d_expand_bn True
# 163 block4d_expand_activation True
# 164 block4d_dwconv True
# 165 block4d_bn True
# 166 block4d_activation True
# 167 block4d_se_squeeze True
# 168 block4d_se_reshape True
# 169 block4d_se_reduce True
# 170 block4d_se_expand True
# 171 block4d_se_excite True
# 172 block4d_project_conv True
# 173 block4d_project_bn True
# 174 block4d_drop True
# 175 block4d_add True
# 176 block5a_expand_conv True
# 177 block5a_expand_bn True
# 178 block5a_expand_activation True
# 179 block5a_dwconv True
# 180 block5a_bn True
# 181 block5a_activation True
# 182 block5a_se_squeeze True
# 183 block5a_se_reshape True
# 184 block5a_se_reduce True
# 185 block5a_se_expand True
# 186 block5a_se_excite True
# 187 block5a_project_conv True
# 188 block5a_project_bn True
# 189 block5b_expand_conv True
# 190 block5b_expand_bn True
# 191 block5b_expand_activation True
# 192 block5b_dwconv True
# 193 block5b_bn True
# 194 block5b_activation True
# 195 block5b_se_squeeze True
# 196 block5b_se_reshape True
# 197 block5b_se_reduce True
# 198 block5b_se_expand True
# 199 block5b_se_excite True
# 200 block5b_project_conv True
# 201 block5b_project_bn True
# 202 block5b_drop True
# 203 block5b_add True
# 204 block5c_expand_conv True
# 205 block5c_expand_bn True
# 206 block5c_expand_activation True
# 207 block5c_dwconv True
# 208 block5c_bn True
# 209 block5c_activation True
# 210 block5c_se_squeeze True
# 211 block5c_se_reshape True
# 212 block5c_se_reduce True
# 213 block5c_se_expand True
# 214 block5c_se_excite True
# 215 block5c_project_conv True
# 216 block5c_project_bn True
# 217 block5c_drop True
# 218 block5c_add True
# 219 block5d_expand_conv True
# 220 block5d_expand_bn True
# 221 block5d_expand_activation True
# 222 block5d_dwconv True
# 223 block5d_bn True
# 224 block5d_activation True
# 225 block5d_se_squeeze True
# 226 block5d_se_reshape True
# 227 block5d_se_reduce True
# 228 block5d_se_expand True
# 229 block5d_se_excite True
# 230 block5d_project_conv True
# 231 block5d_project_bn True
# 232 block5d_drop True
# 233 block5d_add True
# 234 block6a_expand_conv True
# 235 block6a_expand_bn True
# 236 block6a_expand_activation True
# 237 block6a_dwconv_pad True
# 238 block6a_dwconv True
# 239 block6a_bn True
# 240 block6a_activation True
# 241 block6a_se_squeeze True
# 242 block6a_se_reshape True
# 243 block6a_se_reduce True
# 244 block6a_se_expand True
# 245 block6a_se_excite True
# 246 block6a_project_conv True
# 247 block6a_project_bn True
# 248 block6b_expand_conv True
# 249 block6b_expand_bn True
# 250 block6b_expand_activation True
# 251 block6b_dwconv True
# 252 block6b_bn True
# 253 block6b_activation True
# 254 block6b_se_squeeze True
# 255 block6b_se_reshape True
# 256 block6b_se_reduce True
# 257 block6b_se_expand True
# 258 block6b_se_excite True
# 259 block6b_project_conv True
# 260 block6b_project_bn True
# 261 block6b_drop True
# 262 block6b_add True
# 263 block6c_expand_conv True
# 264 block6c_expand_bn True
# 265 block6c_expand_activation True
# 266 block6c_dwconv True
# 267 block6c_bn True
# 268 block6c_activation True
# 269 block6c_se_squeeze True
# 270 block6c_se_reshape True
# 271 block6c_se_reduce True
# 272 block6c_se_expand True
# 273 block6c_se_excite True
# 274 block6c_project_conv True
# 275 block6c_project_bn True
# 276 block6c_drop True
# 277 block6c_add True
# 278 block6d_expand_conv True
# 279 block6d_expand_bn True
# 280 block6d_expand_activation True
# 281 block6d_dwconv True
# 282 block6d_bn True
# 283 block6d_activation True
# 284 block6d_se_squeeze True
# 285 block6d_se_reshape True
# 286 block6d_se_reduce True
# 287 block6d_se_expand True
# 288 block6d_se_excite True
# 289 block6d_project_conv True
# 290 block6d_project_bn True
# 291 block6d_drop True
# 292 block6d_add True
# 293 block6e_expand_conv True
# 294 block6e_expand_bn True
# 295 block6e_expand_activation True
# 296 block6e_dwconv True
# 297 block6e_bn True
# 298 block6e_activation True
# 299 block6e_se_squeeze True
# 300 block6e_se_reshape True
# 301 block6e_se_reduce True
# 302 block6e_se_expand True
# 303 block6e_se_excite True
# 304 block6e_project_conv True
# 305 block6e_project_bn True
# 306 block6e_drop True
# 307 block6e_add True
# 308 block7a_expand_conv True
# 309 block7a_expand_bn True
# 310 block7a_expand_activation True
# 311 block7a_dwconv True
# 312 block7a_bn True
# 313 block7a_activation True
# 314 block7a_se_squeeze True
# 315 block7a_se_reshape True
# 316 block7a_se_reduce True
# 317 block7a_se_expand True
# 318 block7a_se_excite True
# 319 block7a_project_conv True
# 320 block7a_project_bn True
# 321 block7b_expand_conv True
# 322 block7b_expand_bn True
# 323 block7b_expand_activation True
# 324 block7b_dwconv True
# 325 block7b_bn True
# 326 block7b_activation True
# 327 block7b_se_squeeze True
# 328 block7b_se_reshape True
# 329 block7b_se_reduce True
# 330 block7b_se_expand True
# 331 block7b_se_excite True
# 332 block7b_project_conv True
# 333 block7b_project_bn True
# 334 block7b_drop True
# 335 block7b_add True
# 336 top_conv True
# 337 top_bn True
# 338 top_activation True
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# efficientnetb2 (Functional)  (None, 8, 8, 1408)        7768569
# _________________________________________________________________
# gap (GlobalAveragePooling2D) (None, 1408)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1408)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               721408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 8,556,028
# Trainable params: 8,488,453
# Non-trainable params: 67,575
# _________________________________________________________________

# %%
finetuned_model = tl_model
finetuned_model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                 optimizer=tfk.optimizers.Adam(1e-3),
                 metrics=['accuracy',
                          tf.keras.metrics.Recall(name='recall'),
                          tf.keras.metrics.Precision(name='precision'),
                          f1])
finetuned_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# efficientnetb2 (Functional)  (None, 8, 8, 1408)        7768569
# _________________________________________________________________
# gap (GlobalAveragePooling2D) (None, 1408)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1408)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               721408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 8,556,028
# Trainable params: 8,488,453
# Non-trainable params: 67,575
# _________________________________________________________________

# %%
# Train the model
history = finetuned_model.fit(
    x = train_set,
    epochs = 100,
    validation_data = validation_set,
    callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_f1', patience=10, restore_best_weights=True, mode='max'),
                 tf.keras.callbacks.ReduceLROnPlateau(monitor='val_f1', patience=5, factor=0.1, verbose=1, mode='max')]
).history
# Out:
# Epoch 1/100
# 339/339 [==============================] - 239s 630ms/step - loss: 0.2806 - accuracy: 0.8985 - recall: 0.8945 - precision: 0.9030 - f1: 0.8987 - val_loss: 0.2278 - val_accuracy: 0.9347 - val_recall: 0.9330 - val_precision: 0.9370 - val_f1: 0.9330
# Epoch 2/100
# 339/339 [==============================] - 212s 624ms/step - loss: 0.1693 - accuracy: 0.9387 - recall: 0.9371 - precision: 0.9407 - f1: 0.9388 - val_loss: 0.1774 - val_accuracy: 0.9351 - val_recall: 0.9338 - val_precision: 0.9362 - val_f1: 0.9332
# Epoch 3/100
# 339/339 [==============================] - 212s 624ms/step - loss: 0.1210 - accuracy: 0.9587 - recall: 0.9571 - precision: 0.9603 - f1: 0.9585 - val_loss: 0.1229 - val_accuracy: 0.9557 - val_recall: 0.9553 - val_precision: 0.9557 - val_f1: 0.9549
# Epoch 4/100
# 339/339 [==============================] - 211s 621ms/step - loss: 0.0992 - accuracy: 0.9669 - recall: 0.9653 - precision: 0.9681 - f1: 0.9666 - val_loss: 0.1295 - val_accuracy: 0.9609 - val_recall: 0.9587 - val_precision: 0.9621 - val_f1: 0.9601
# Epoch 5/100
# 339/339 [==============================] - 211s 623ms/step - loss: 0.0902 - accuracy: 0.9682 - recall: 0.9673 - precision: 0.9690 - f1: 0.9681 - val_loss: 0.1031 - val_accuracy: 0.9622 - val_recall: 0.9600 - val_precision: 0.9650 - val_f1: 0.9620
# Epoch 6/100
# 339/339 [==============================] - 211s 623ms/step - loss: 0.0766 - accuracy: 0.9740 - recall: 0.9737 - precision: 0.9746 - f1: 0.9741 - val_loss: 0.0986 - val_accuracy: 0.9695 - val_recall: 0.9691 - val_precision: 0.9699 - val_f1: 0.9692
# Epoch 7/100
# 339/339 [==============================] - 211s 623ms/step - loss: 0.0722 - accuracy: 0.9764 - recall: 0.9754 - precision: 0.9770 - f1: 0.9762 - val_loss: 0.1889 - val_accuracy: 0.9385 - val_recall: 0.9364 - val_precision: 0.9404 - val_f1: 0.9379
# Epoch 8/100
# 339/339 [==============================] - 211s 624ms/step - loss: 0.0701 - accuracy: 0.9767 - recall: 0.9754 - precision: 0.9776 - f1: 0.9764 - val_loss: 0.1248 - val_accuracy: 0.9540 - val_recall: 0.9536 - val_precision: 0.9565 - val_f1: 0.9548
# Epoch 9/100
# 339/339 [==============================] - 211s 623ms/step - loss: 0.0557 - accuracy: 0.9826 - recall: 0.9819 - precision: 0.9827 - f1: 0.9822 - val_loss: 0.1786 - val_accuracy: 0.9575 - val_recall: 0.9562 - val_precision: 0.9574 - val_f1: 0.9562
# Epoch 10/100
# 339/339 [==============================] - 211s 622ms/step - loss: 0.0521 - accuracy: 0.9820 - recall: 0.9816 - precision: 0.9825 - f1: 0.9820 - val_loss: 0.1289 - val_accuracy: 0.9630 - val_recall: 0.9626 - val_precision: 0.9639 - val_f1: 0.9632
# Epoch 11/100
# 339/339 [==============================] - 211s 622ms/step - loss: 0.0367 - accuracy: 0.9890 - recall: 0.9886 - precision: 0.9892 - f1: 0.9889 - val_loss: 0.1877 - val_accuracy: 0.9411 - val_recall: 0.9385 - val_precision: 0.9442 - val_f1: 0.9408
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/100
# 339/339 [==============================] - 210s 618ms/step - loss: 0.0162 - accuracy: 0.9950 - recall: 0.9949 - precision: 0.9955 - f1: 0.9952 - val_loss: 0.1150 - val_accuracy: 0.9695 - val_recall: 0.9691 - val_precision: 0.9703 - val_f1: 0.9695
# Epoch 13/100
# 339/339 [==============================] - 210s 621ms/step - loss: 0.0067 - accuracy: 0.9976 - recall: 0.9976 - precision: 0.9976 - f1: 0.9976 - val_loss: 0.1255 - val_accuracy: 0.9699 - val_recall: 0.9695 - val_precision: 0.9707 - val_f1: 0.9698
# Epoch 14/100
# 339/339 [==============================] - 209s 617ms/step - loss: 0.0026 - accuracy: 0.9992 - recall: 0.9992 - precision: 0.9993 - f1: 0.9992 - val_loss: 0.1385 - val_accuracy: 0.9712 - val_recall: 0.9712 - val_precision: 0.9716 - val_f1: 0.9712
# Epoch 15/100
# 339/339 [==============================] - 210s 619ms/step - loss: 0.0033 - accuracy: 0.9992 - recall: 0.9992 - precision: 0.9992 - f1: 0.9992 - val_loss: 0.1470 - val_accuracy: 0.9729 - val_recall: 0.9729 - val_precision: 0.9729 - val_f1: 0.9727
# Epoch 16/100
# 339/339 [==============================] - 211s 622ms/step - loss: 0.0016 - accuracy: 0.9994 - recall: 0.9994 - precision: 0.9994 - f1: 0.9994 - val_loss: 0.1392 - val_accuracy: 0.9729 - val_recall: 0.9729 - val_precision: 0.9729 - val_f1: 0.9729
# Epoch 17/100
# 339/339 [==============================] - 211s 622ms/step - loss: 0.0024 - accuracy: 0.9991 - recall: 0.9991 - precision: 0.9991 - f1: 0.9991 - val_loss: 0.1456 - val_accuracy: 0.9725 - val_recall: 0.9725 - val_precision: 0.9725 - val_f1: 0.9724
# Epoch 18/100
# 339/339 [==============================] - 211s 623ms/step - loss: 0.0025 - accuracy: 0.9994 - recall: 0.9994 - precision: 0.9994 - f1: 0.9994 - val_loss: 0.1303 - val_accuracy: 0.9738 - val_recall: 0.9738 - val_precision: 0.9738 - val_f1: 0.9737
# Epoch 19/100
# 339/339 [==============================] - 211s 624ms/step - loss: 0.0028 - accuracy: 0.9992 - recall: 0.9992 - precision: 0.9992 - f1: 0.9992 - val_loss: 0.1328 - val_accuracy: 0.9751 - val_recall: 0.9751 - val_precision: 0.9751 - val_f1: 0.9750
# Epoch 20/100
# 339/339 [==============================] - 211s 623ms/step - loss: 8.6541e-04 - accuracy: 0.9999 - recall: 0.9999 - precision: 0.9999 - f1: 0.9999 - val_loss: 0.1430 - val_accuracy: 0.9768 - val_recall: 0.9764 - val_precision: 0.9772 - val_f1: 0.9767
# Epoch 21/100
# 339/339 [==============================] - 211s 622ms/step - loss: 8.7825e-04 - accuracy: 0.9997 - recall: 0.9997 - precision: 0.9997 - f1: 0.9997 - val_loss: 0.1535 - val_accuracy: 0.9751 - val_recall: 0.9751 - val_precision: 0.9751 - val_f1: 0.9750
# Epoch 22/100
# 339/339 [==============================] - 212s 624ms/step - loss: 7.9704e-04 - accuracy: 0.9997 - recall: 0.9997 - precision: 0.9997 - f1: 0.9997 - val_loss: 0.1567 - val_accuracy: 0.9742 - val_recall: 0.9742 - val_precision: 0.9742 - val_f1: 0.9741
# Epoch 23/100
# 339/339 [==============================] - 211s 622ms/step - loss: 3.8622e-04 - accuracy: 0.9999 - recall: 0.9999 - precision: 0.9999 - f1: 0.9999 - val_loss: 0.1678 - val_accuracy: 0.9759 - val_recall: 0.9759 - val_precision: 0.9764 - val_f1: 0.9761
# Epoch 24/100
# 339/339 [==============================] - 211s 623ms/step - loss: 3.4706e-04 - accuracy: 0.9998 - recall: 0.9998 - precision: 0.9998 - f1: 0.9998 - val_loss: 0.1731 - val_accuracy: 0.9738 - val_recall: 0.9738 - val_precision: 0.9738 - val_f1: 0.9736
# Epoch 25/100
# 339/339 [==============================] - 211s 623ms/step - loss: 0.0016 - accuracy: 0.9993 - recall: 0.9993 - precision: 0.9994 - f1: 0.9993 - val_loss: 0.1951 - val_accuracy: 0.9725 - val_recall: 0.9725 - val_precision: 0.9725 - val_f1: 0.9716
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 26/100
# 339/339 [==============================] - 212s 624ms/step - loss: 0.0011 - accuracy: 0.9997 - recall: 0.9997 - precision: 0.9997 - f1: 0.9997 - val_loss: 0.1586 - val_accuracy: 0.9746 - val_recall: 0.9746 - val_precision: 0.9746 - val_f1: 0.9742
# Epoch 27/100
# 339/339 [==============================] - 213s 629ms/step - loss: 0.0016 - accuracy: 0.9995 - recall: 0.9995 - precision: 0.9995 - f1: 0.9995 - val_loss: 0.1544 - val_accuracy: 0.9746 - val_recall: 0.9746 - val_precision: 0.9746 - val_f1: 0.9744
# Epoch 28/100
# 339/339 [==============================] - 211s 623ms/step - loss: 0.0011 - accuracy: 0.9996 - recall: 0.9996 - precision: 0.9996 - f1: 0.9996 - val_loss: 0.1569 - val_accuracy: 0.9742 - val_recall: 0.9742 - val_precision: 0.9742 - val_f1: 0.9740
# Epoch 29/100
# 339/339 [==============================] - 212s 625ms/step - loss: 5.7326e-04 - accuracy: 0.9997 - recall: 0.9997 - precision: 0.9997 - f1: 0.9997 - val_loss: 0.1566 - val_accuracy: 0.9746 - val_recall: 0.9746 - val_precision: 0.9746 - val_f1: 0.9744
# Epoch 30/100
# 339/339 [==============================] - 212s 625ms/step - loss: 8.0593e-04 - accuracy: 0.9996 - recall: 0.9996 - precision: 0.9996 - f1: 0.9996 - val_loss: 0.1564 - val_accuracy: 0.9742 - val_recall: 0.9742 - val_precision: 0.9742 - val_f1: 0.9740
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.

# %%
finetuned_model.save('/kaggle/working/finetuning')

# %%
# !zip -r efficientnetb2_FT.zip /kaggle/working/finetuning
from IPython.display import FileLink 
FileLink(r'efficientnetb2_FT.zip')
# Out:
#   adding: kaggle/working/finetuning/ (stored 0%)
#   adding: kaggle/working/finetuning/variables/ (stored 0%)
#   adding: kaggle/working/finetuning/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/finetuning/variables/variables.index (deflated 78%)
#   adding: kaggle/working/finetuning/assets/ (stored 0%)
#   adding: kaggle/working/finetuning/keras_metadata.pb (deflated 96%)
#   adding: kaggle/working/finetuning/saved_model.pb (deflated 91%)
# /kaggle/working/efficientnetb2_FT.zip

# %% [markdown]
# ### Fine Tuning: results

# %% [markdown]
# ##### Validation

# %%
finetuned_model.evaluate(validation_set)
# Out:
# 73/73 [==============================] - 9s 121ms/step - loss: 0.1430 - accuracy: 0.9768 - recall: 0.9764 - precision: 0.9772 - f1: 0.9767
# [0.14296555519104004,
#  0.9767941832542419,
#  0.9763644337654114,
#  0.9772043228149414,
#  0.9766887426376343]

# %%
val_predictions = finetuned_model.predict(validation_set)
y_val = validation_set.labels

# %%
print_evaluation(y_val, np.argmax(val_predictions, axis=-1))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9804    0.9845    0.9824      1420
#            1     0.9781    0.9843    0.9812       635
#            2     0.9542    0.9191    0.9363       272
#
#     accuracy                         0.9768      2327
#    macro avg     0.9709    0.9626    0.9666      2327
# weighted avg     0.9767    0.9768    0.9767      2327

# %% [markdown]
# ##### Test

# %%
finetuned_model.evaluate(test_set)
# Out:
# 73/73 [==============================] - 9s 120ms/step - loss: 0.1965 - accuracy: 0.9693 - recall: 0.9693 - precision: 0.9697 - f1: 0.9698
# [0.19645550847053528,
#  0.9692507386207581,
#  0.9692507386207581,
#  0.9696707129478455,
#  0.9698031544685364]

# %%
val_predictions = finetuned_model.predict(test_set)
y_val = test_set.labels

# %%
print_evaluation(y_val, np.argmax(val_predictions, axis=-1))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9695    0.9806    0.9750      1392
#            1     0.9734    0.9811    0.9772       634
#            2     0.9580    0.8869    0.9211       283
#
#     accuracy                         0.9693      2309
#    macro avg     0.9670    0.9495    0.9578      2309
# weighted avg     0.9691    0.9693    0.9690      2309
